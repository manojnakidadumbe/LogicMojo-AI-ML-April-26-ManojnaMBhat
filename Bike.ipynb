# %% [markdown]
# <a href="https://colab.research.google.com/github/manojnakidadumbe/LogicMojo-AI-ML-April-26-ManojnaMBhat/blob/main/Bike.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#filtering out the warnings

import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.listdir('/content/drive/My Drive/Colab Notebooks/LR Assignment')
# Out:
# ['Bike.ipynb', 'day.xlsx']

# %%
df = pd.read_excel('/content/drive/My Drive/Colab Notebooks/LR Assignment/day.xlsx')

# %%
df.head()
# Out:
#    instant               dteday  season  yr  mnth  holiday  weekday  \
# 0        1  2018-01-01 00:00:00       1   0     1        0        1
# 1        2  2018-02-01 00:00:00       1   0     1        0        2
# 2        3  2018-03-01 00:00:00       1   0     1        0        3
# 3        4  2018-04-01 00:00:00       1   0     1        0        4
# 4        5  2018-05-01 00:00:00       1   0     1        0        5
#
#    workingday  weathersit       temp     atemp      hum  windspeed  casual  \
# 0           1           2  14.110847  18.18125  80.5833  10.749882     331
# 1           1           2  14.902598  17.68695  69.6087  16.652113     131
# 2           1           1   8.050924   9.47025  43.7273  16.636703     120
# 3           1           1   8.200000  10.60610  59.0435  10.739832     108
# 4           1           1   9.305237  11.46350  43.6957  12.522300      82
#
#    registered   cnt
# 0         654   985
# 1         670   801
# 2        1229  1349
# ...

# %%
df.shape
# Out:
# (730, 16)

# %%
df.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  730.000000  730.000000  730.000000  730.000000  730.000000  730.000000
# mean   365.500000    2.498630    0.500000    6.526027    0.028767    2.995890
# std    210.877136    1.110184    0.500343    3.450215    0.167266    2.000339
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.250000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    365.500000    3.000000    0.500000    7.000000    0.000000    3.000000
# 75%    547.750000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    730.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  730.000000  730.000000  730.000000  730.000000  730.000000  730.000000
# mean     0.690411    1.394521   20.319259   23.726322   62.765175   12.763620
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     730 non-null    int64
#  1   dteday      730 non-null    object
#  2   season      730 non-null    int64
#  3   yr          730 non-null    int64
#  4   mnth        730 non-null    int64
#  5   holiday     730 non-null    int64
#  6   weekday     730 non-null    int64
#  7   workingday  730 non-null    int64
#  8   weathersit  730 non-null    int64
#  9   temp        730 non-null    float64
#  10  atemp       730 non-null    float64
#  11  hum         730 non-null    float64
#  12  windspeed   730 non-null    float64
#  13  casual      730 non-null    int64
#  14  registered  730 non-null    int64
#  15  cnt         730 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.4+ KB

# %%
df.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 725    False
# 726    False
# 727    False
# 728    False
# 729    False
# Length: 730, dtype: bool

# %%
cat_cols = ['season','yr','mnth','holiday','weekday','workingday','weathersit']
num_cols = ['temp','atemp','hum','windspeed','casual','registered', 'cnt']

# %%
cat_cols = ['season','yr','mnth','holiday','weekday','workingday','weathersit']

for col in cat_cols:
  plt.figure(figsize=(10,5))
  plt.title(col)
  sns.countplot(x = col, data = df)
  plt.show()

# %%
num_cols = ['temp','atemp','hum','windspeed','casual','registered', 'cnt']

for col in num_cols:
  plt.figure(figsize=(10,5))
  plt.title(col)
  sns.histplot(x = col, data = df, kde = True)
  plt.show()

# %%
num_cols = ['temp','atemp','hum','windspeed','casual','registered', 'cnt']

for col in num_cols:
  plt.figure(figsize=(10,5))
  plt.title(col)
  sns.boxplot(x = col, data = df)
  plt.show()

# %%
cat_cols = ['season','yr','mnth','holiday','weekday','workingday','weathersit']

for col in cat_cols:
  plt.figure(figsize=(10,5))
  plt.title(col)
  sns.boxplot(x = col, y = 'cnt', data = df)
  plt.show()

# %%
num_cols = ['temp','atemp','hum','windspeed','casual','registered']

for col in num_cols:
  plt.figure(figsize=(10,5))
  plt.title(col)
  sns.scatterplot(x = col, y = 'cnt', data = df)
  plt.show()

# %%
corr = df.corr(numeric_only=True)
plt.figure(figsize=(10,5))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.show()

# %%
df[['casual', 'registered', 'cnt']].head(10)
# Out:
#    casual  registered   cnt
# 0     331         654   985
# 1     131         670   801
# 2     120        1229  1349
# 3     108        1454  1562
# 4      82        1518  1600
# 5      88        1518  1606
# 6     148        1362  1510
# 7      68         891   959
# 8      54         768   822
# 9      41        1280  1321

# %%
(df['casual'] + df['registered'] == df['cnt']).all()
# Out:
# np.True_

# %%
df = df.drop(['dteday', 'casual', 'registered', 'instant'], axis = 1)

# %%
df.columns
# Out:
# Index(['season', 'yr', 'mnth', 'holiday', 'weekday', 'workingday',
#        'weathersit', 'temp', 'atemp', 'hum', 'windspeed', 'cnt'],
#       dtype='object')

# %%
df_cat = pd.get_dummies(df[cat_cols], drop_first = True)

df_num = df[['temp','atemp','hum','windspeed','cnt']]

df = pd.concat([df_num, df_cat], axis = 1)

df.head()
# Out:
#         temp     atemp      hum  windspeed   cnt  season  yr  mnth  holiday  \
# 0  14.110847  18.18125  80.5833  10.749882   985       1   0     1        0
# 1  14.902598  17.68695  69.6087  16.652113   801       1   0     1        0
# 2   8.050924   9.47025  43.7273  16.636703  1349       1   0     1        0
# 3   8.200000  10.60610  59.0435  10.739832  1562       1   0     1        0
# 4   9.305237  11.46350  43.6957  12.522300  1600       1   0     1        0
#
#    weekday  workingday  weathersit
# 0        1           1           2
# 1        2           1           2
# 2        3           1           1
# 3        4           1           1
# 4        5           1           1

# %%
df = pd.get_dummies(df, columns=cat_cols, drop_first=True)

# %%
df.head()
# Out:
#         temp     atemp      hum  windspeed   cnt  season_2  season_3  \
# 0  14.110847  18.18125  80.5833  10.749882   985     False     False
# 1  14.902598  17.68695  69.6087  16.652113   801     False     False
# 2   8.050924   9.47025  43.7273  16.636703  1349     False     False
# 3   8.200000  10.60610  59.0435  10.739832  1562     False     False
# 4   9.305237  11.46350  43.6957  12.522300  1600     False     False
#
#    season_4   yr_1  mnth_2  ...  holiday_1  weekday_1  weekday_2  weekday_3  \
# 0     False  False   False  ...      False       True      False      False
# 1     False  False   False  ...      False      False       True      False
# 2     False  False   False  ...      False      False      False       True
# 3     False  False   False  ...      False      False      False      False
# 4     False  False   False  ...      False      False      False      False
#
#    weekday_4  weekday_5  weekday_6  workingday_1  weathersit_2  weathersit_3
# ...

# %%
from sklearn.model_selection import train_test_split

X = df.drop('cnt', axis = 1)
y = df['cnt']

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    train_size = 0.8,
    random_state = 101
)

# %%
print(X_train.shape)
# Out:
# (584, 29)

# %%
print(X_test.shape)
# Out:
# (146, 29)

# %%
print(y_train.shape)
# Out:
# (584,)

# %%
print(y_test.shape)
# Out:
# (146,)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lr.intercept_
# Out:
# np.float64(1960.1666671626454)

# %%
lr.coef_
# Out:
# array([    8.19364635,    92.4350508 ,   -16.64826557,   -44.86379496,
#          700.20409006,   591.97921459,  1603.89234408,  2028.2347348 ,
#          140.24184607,   618.81731682,   590.21377163,   896.39106764,
#          646.51620608,   290.82481422,   663.6683854 ,  1113.93716044,
#          417.0268664 ,  -181.13262207,  -120.8660071 , -1376.65639257,
#          602.50553638,   443.08952553,   600.01367301,   712.43162157,
#          718.22851135,   -83.41763752,  -820.15500336,  -433.85823539,
#        -1880.24487072])

# %%
pd.DataFrame({
    'Features': X_train.columns,
    'Coefficients': lr.coef_
    })
# Out:
#         Features  Coefficients
# 0           temp      8.193646
# 1          atemp     92.435051
# 2            hum    -16.648266
# 3      windspeed    -44.863795
# 4       season_2    700.204090
# 5       season_3    591.979215
# 6       season_4   1603.892344
# 7           yr_1   2028.234735
# 8         mnth_2    140.241846
# 9         mnth_3    618.817317
# 10        mnth_4    590.213772
# 11        mnth_5    896.391068
# 12        mnth_6    646.516206
# 13        mnth_7    290.824814
# 14        mnth_8    663.668385
# 15        mnth_9   1113.937160
# 16       mnth_10    417.026866
# 17       mnth_11   -181.132622
# 18       mnth_12   -120.866007
# 19     holiday_1  -1376.656393
# 20     weekday_1    602.505536
# 21     weekday_2    443.089526
# 22     weekday_3    600.013673
# 23     weekday_4    712.431622
# 24     weekday_5    718.228511
# 25     weekday_6    -83.417638
# 26  workingday_1   -820.155003
# 27  weathersit_2   -433.858235
# 28  weathersit_3  -1880.244871

# %%
Y_pred = lr.predict(X_test)

# %%
print(Y_pred[:5])
# Out:
# [3786.23855916 2385.38392885 6784.93021084 5642.3028216  4039.33989924]

# %%
comparision = pd.DataFrame({
    'Actual': y_test,
    'Predicted': Y_pred
})
comparision.head()
# Out:
#      Actual    Predicted
# 299    2659  3786.238559
# 723    1013  2385.383929
# 647    7691  6784.930211
# 520    7001  5642.302822
# 114    4073  4039.339899

# %%
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(y_test, Y_pred)
print(mae)
# Out:
# 602.3909156015783

# %%
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y_test, Y_pred)
print(mse)
# Out:
# 646990.5590957477

# %%
rmse = np.sqrt(mse)
print(rmse)
# Out:
# 804.3572335074433

# %%
from sklearn.metrics import r2_score

r2 = r2_score(y_test, Y_pred)
print(r2)
# Out:
# 0.8348668097882023
